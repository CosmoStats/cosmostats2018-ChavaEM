# %% [markdown]
# ## Parte 1 del Ejercicio 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams

# %matplotlib inline
rcParams['figure.figsize'] = (10,10)

# %% [markdown]
# ### Caja con puntos en una malla cuadriculada

# %%
lado = 100 #Tamaño de la caja
xmalla, ymalla = [], []

#Puntos de la malla cuadriculada
for i in range(0, lado+1, 10):
    for j in range(0, lado+1, 10):
        xmalla.append(j)
        ymalla.append(i)

#Caja de malla cuadriculada
plt.plot(xmalla,ymalla, ',')
plt.gca().set_aspect('equal')

# %% [markdown]
# ### Caja con puntos aleatorios en disco de radio 300

# %%
lado = 1000 #Tamaño de la caja
radio = 300 #Radio del disco
puntos = 1000 #Numero de puntos en la caja

i = 0
xdisco, ydisco = [], []

#Generamos los puntos aleatorios en el disco
while i < puntos:
    
    #X y Y son las coordenadas de los puntos
    X = lado*(np.random.random()-0.5)
    Y = lado*(np.random.random()-0.5)
    
    if X**2 + Y**2 > radio**2: #Si las coordenadas estan fuera del circulo las descartamos
        continue
        
    #Agregamos al arreglo las coordenadas que esten dentro del disco
    xdisco.append(X)
    ydisco.append(Y)
    i += 1

#Graficamos el disco
plt.plot(xdisco,ydisco, '.')
plt.gca().set_aspect('equal')
plt.xlim(-lado/2, lado/2)
plt.ylim(-lado/2, lado/2)
# Out:
# (-500.0, 500.0)

# %%
def anillo(R, r, c, puntos, lado): #Radio mayor, radio menor, centro, numero de puntos, lado de la caja
    x0, y0 = c
    i = 0 #Contador
    x, y = [], [] #Arreglos de las coordenadas
    
    #Generamos los puntos aleatorios en el anillo
    while i < puntos:
        
        #X y Y son las coordenadas de los puntos
        X = lado*(np.random.random()-0.5) + x0
        Y = lado*(np.random.random()-0.5) + y0
        
        if (X-x0)**2 + (Y-y0)**2 > R**2 or (X-x0)**2 + (Y-y0)**2 < r**2: #Si las coordenadas estan fuera del anillo las descartamos
            continue
            
        #Agregamos al arreglo las coordenadas que esten dentro del anillo y de la caja
        if (X < lado * 0.5 or X > -lado*0.5) and (Y < lado * 0.5 or Y > -lado*0.5):
            x.append(X)
            y.append(Y)
        i += 1
    #Graficamos el anillo
    return x, y

# %% [markdown]
# ### Caja con puntos aleatorios en anillo de radios 290 y 300

# %%
lado = 1000 #Tamaño de la caja
radioM = 300 #Radio mayor del anillo
radiom = 290 #Radio menor del anillo
puntos = 1000 #Numero de puntos en el anillo
c = (0,0) #Centro del anillo

xanillo, yanillo = anillo(radioM, radiom, c, puntos, lado)

plt.plot(xanillo,yanillo, 'b,')
plt.gca().set_aspect('equal')
plt.xlim(-lado/2, lado/2)
plt.ylim(-lado/2, lado/2)
# Out:
# (-500.0, 500.0)

# %% [markdown]
# ### Caja con puntos aleatorios en anillos de centro y radio aleatorios

# %%
lado = 1000 #Lado de la caja
Nanillos = 50 #Numero de anillos
puntos = 100 #Numero de puntos en cada anillo

c = [(lado*(np.random.random()-0.5), lado*(np.random.random()-0.5)) for i in range(Nanillos)] #Centros de los anillos
r = [radiom*np.random.random() for i in range(Nanillos)] #Radios aleatorios de los anillos

#Graficamos cada anillo

xanillos, yanillos = [0 for i in range(Nanillos)], [0 for i in range(Nanillos)]

for i in range(Nanillos):
    xanillos[i], yanillos[i] = anillo(r[i] + 10, r[i], c[i], puntos, lado)
    plt.plot(xanillos[i],yanillos[i], 'b,')
    plt.gca().set_aspect('equal')
    plt.xlim(-lado/2, lado/2)
    plt.ylim(-lado/2, lado/2)

# %% [markdown]
# ### Caja con puntos aleatorios en anillos de centro aleatorio y radio fijo

# %%
lado = 1000 #Lado de la caja
Nanillos = 50 #Numero de anillos
puntos = 100 #Numero de puntos en cada anillo
r = 100 #Radio menor de los anillos
R = r +10 #Radio mayor de los anillos

c = [(lado*(np.random.random()-0.5), lado*(np.random.random()-0.5)) for i in range(Nanillos)] #Centros de los anillos

xAnillos, yAnillos = [0 for i in range(Nanillos)], [0 for i in range(Nanillos)]

for i in range(Nanillos):
    xAnillos[i], yAnillos[i] = anillo(R, r, c[i], puntos, lado)
    plt.plot(xAnillos[i],yAnillos[i], 'b,')
    plt.gca().set_aspect('equal')
    plt.xlim(-lado/2, lado/2)
    plt.ylim(-lado/2, lado/2)

# %% [markdown]
# ## Parte 2

# %%
def distancia(x1,y1,x2,y2):
    n = len(x1)
    d = [0 for i in range(int(n(n-1)/2))]
    for i in range(len(x1)-1):
        for j in range(i+1, len(x1)):
            d[i](np.sqrt((x2[j]-x1[i])**2 + (y2[j]-y1[i])**2))
    return d

# %%
d = distancia(xmalla, ymalla, xmalla, ymalla)
# Out:
# [10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90.0, 100.0, 10.0, 14.142135623730951, 22.360679774997898, 31.622776601683793, 41.23105625617661, 50.99019513592785, 60.8276253029822, 70.71067811865476, 80.62257748298549, 90.55385138137417, 100.4987562112089, 20.0, 22.360679774997898, 28.284271247461902, 36.05551275463989, 44.721359549995796, 53.85164807134504, 63.245553203367585, 72.80109889280519, 82.46211251235322, 92.19544457292888, 101.9803902718557, 30.0, 31.622776601683793, 36.05551275463989, 42.42640687119285, 50.0, 58.309518948453004, 67.08203932499369, 76.15773105863909, 85.44003745317531, 94.86832980505137, 104.4030650891055, 40.0, 41.23105625617661, 44.721359549995796, 50.0, 56.568542494923804, 64.03124237432849, 72.11102550927978, 80.62257748298549, 89.44271909999159, 98.48857801796105, 107.70329614269008, 50.0, 50.99019513592785, 53.85164807134504, 58.309518948453004, 64.03124237432849, 70.71067811865476, 78.10249675906654, 86.02325267042627, 94.33981132056604, 102.95630140987001, 111.80339887498948, 60.0, 60.8276253029822, 63.245553203367585, 67.08